# %% [markdown]
# # While Loops, Break and Continue - Lab

# %% [markdown]
# ## Introduction
# In this lab, we will practice using `while` loops, and `break` and `continue` statements in our code. We will use our control flow statements to iterate through collections and filter out or selectively operate on each element. We'll use `while` loops to perform operations until a given condition is no longer true.

# %% [markdown]
# ## Objectives
# You will be able to:
# * Use a break and continue statements inside a loop
# * Understand, explain and use while loops

# %% [markdown]
# ## Instructions
#
# ### While Loops
# Use while loops to perform the below operations and get the expected return values

# %%
slices_of_pie = 6
slices_eaten = 0
# use a while loop to eat each slice of pie
# add each slice to the slices_eaten variable
for slice in range(slices_of_pie):
    while slice < 6:
        print(slice)
        print('Another slice eaten!')
        slices_eaten += 1
        print('Now eaten {} slices!'.format(slices_eaten))
# Out:
# 0
# Another slice eaten!
# Now eaten 1 slices!
# 0
# Another slice eaten!
# Now eaten 2 slices!
# 0
# Another slice eaten!
# Now eaten 3 slices!
# 0
# Another slice eaten!
# Now eaten 4 slices!
# 0
# Another slice eaten!
# Now eaten 5 slices!
# 0
# Another slice eaten!
# Now eaten 6 slices!
# 0
# Another slice eaten!
# Now eaten 7 slices!
# 0
# Another slice eaten!
# Now eaten 8 slices!
# 0
# Another slice eaten!
# Now eaten 9 slices!
# 0
# Another slice eaten!
# Now eaten 10 slices!
# 0
# Another slice eaten!
# Now eaten 11 slices!
# 0
# Another slice eaten!
# Now eaten 12 slices!
# 0
# Another slice eaten!
# Now eaten 13 slices!
# 0
# Another slice eaten!
# Now eaten 14 slices!
# 0
# Another slice eaten!
# Now eaten 15 slices!
# 0
# Another slice eaten!
# Now eaten 16 slices!
# 0
# Another slice eaten!
# Now eaten 17 slices!
# 0
# Another slice eaten!
# Now eaten 18 slices!
# 0
# Another slice eaten!
# Now eaten 19 slices!
# 0
# Another slice eaten!
# Now eaten 20 slices!
# 0
# Another slice eaten!
# Now eaten 21 slices!
# 0
# Another slice eaten!
# Now eaten 22 slices!
# 0
# Another slice eaten!
# Now eaten 23 slices!
# 0
# Another slice eaten!
# Now eaten 24 slices!
# 0
# Another slice eaten!
# Now eaten 25 slices!
# 0
# Another slice eaten!
# Now eaten 26 slices!
# 0
# Another slice eaten!
# Now eaten 27 slices!
# 0
# Another slice eaten!
# Now eaten 28 slices!
# 0
# Another slice eaten!
# Now eaten 29 slices!
# 0
# Another slice eaten!
# Now eaten 30 slices!
# 0
# Another slice eaten!
# Now eaten 31 slices!
# 0
# Another slice eaten!
# Now eaten 32 slices!
# 0
# Another slice eaten!
# Now eaten 33 slices!
# 0
# Another slice eaten!
# Now eaten 34 slices!
# 0
# Another slice eaten!
# Now eaten 35 slices!
# 0
# Another slice eaten!
# Now eaten 36 slices!
# 0
# Another slice eaten!
# Now eaten 37 slices!
# 0
# Another slice eaten!
# Now eaten 38 slices!
# 0
# Another slice eaten!
# Now eaten 39 slices!
# 0
# Another slice eaten!
# Now eaten 40 slices!
# 0
# Another slice eaten!
# Now eaten 41 slices!
# 0
# Another slice eaten!
# Now eaten 42 slices!
# 0
# Another slice eaten!
# Now eaten 43 slices!
# 0
# Another slice eaten!
# Now eaten 44 slices!
# 0
# Another slice eaten!
# Now eaten 45 slices!
# 0
# Another slice eaten!
# Now eaten 46 slices!
# 0
# Another slice eaten!
# Now eaten 47 slices!
# 0
# Another slice eaten!
# Now eaten 48 slices!
# 0
# Another slice eaten!
# Now eaten 49 slices!
# 0
# Another slice eaten!
# Now eaten 50 slices!
# 0
# Another slice eaten!
# Now eaten 51 slices!
# 0
# Another slice eaten!
# Now eaten 52 slices!
# 0
# Another slice eaten!
# Now eaten 53 slices!
# 0
# Another slice eaten!
# Now eaten 54 slices!
# 0
# Another slice eaten!
# Now eaten 55 slices!
# 0
# Another slice eaten!
# Now eaten 56 slices!
# 0
# Another slice eaten!
# Now eaten 57 slices!
# 0
# Another slice eaten!
# Now eaten 58 slices!
# 0
# Another slice eaten!
# Now eaten 59 slices!
# 0
# Another slice eaten!
# Now eaten 60 slices!
# 0
# Another slice eaten!
# Now eaten 61 slices!
# 0
# Another slice eaten!
# Now eaten 62 slices!
# 0
# Another slice eaten!
# Now eaten 63 slices!
# 0
# Another slice eaten!
# Now eaten 64 slices!
# 0
# Another slice eaten!
# Now eaten 65 slices!
# 0
# Another slice eaten!
# Now eaten 66 slices!
# 0
# Another slice eaten!
# Now eaten 67 slices!
# 0
# Another slice eaten!
# Now eaten 68 slices!
# 0
# Another slice eaten!
# Now eaten 69 slices!
# 0
# Another slice eaten!
# Now eaten 70 slices!
# 0
# Another slice eaten!
# Now eaten 71 slices!
# 0
# Another slice eaten!
# Now eaten 72 slices!
# 0
# Another slice eaten!
# Now eaten 73 slices!
# 0
# Another slice eaten!
# Now eaten 74 slices!
# 0
# Another slice eaten!
# Now eaten 75 slices!
# 0
# Another slice eaten!
# Now eaten 76 slices!
# 0
# Another slice eaten!
# Now eaten 77 slices!
# 0
# Another slice eaten!
# Now eaten 78 slices!
# 0
# Another slice eaten!
# Now eaten 79 slices!
# 0
# Another slice eaten!
# Now eaten 80 slices!
# 0
# Another slice eaten!
# Now eaten 81 slices!
# 0
# Another slice eaten!
# Now eaten 82 slices!
# 0
# Another slice eaten!
# Now eaten 83 slices!
# 0
# Another slice eaten!
# Now eaten 84 slices!
# 0
# Another slice eaten!
# Now eaten 85 slices!
# 0
# Another slice eaten!
# Now eaten 86 slices!
# 0
# Another slice eaten!
# Now eaten 87 slices!
# 0
# Another slice eaten!
# Now eaten 88 slices!
# 0
# Another slice eaten!
# Now eaten 89 slices!
# 0
# Another slice eaten!
# Now eaten 90 slices!
# 0
# Another slice eaten!
# Now eaten 91 slices!
# 0
# Another slice eaten!
# Now eaten 92 slices!
# 0
# Another slice eaten!
# Now eaten 93 slices!
# 0
# Another slice eaten!
# Now eaten 94 slices!
# 0
# Another slice eaten!
# Now eaten 95 slices!
# 0
# Another slice eaten!
# Now eaten 96 slices!
# 0
# Another slice eaten!
# Now eaten 97 slices!
# 0
# Another slice eaten!
# Now eaten 98 slices!
# 0
# Another slice eaten!
# Now eaten 99 slices!
# 0
# Another slice eaten!
# Now eaten 100 slices!
# 0
# Another slice eaten!
# Now eaten 101 slices!
# 0
# Another slice eaten!
# Now eaten 102 slices!
# 0
# Another slice eaten!
# Now eaten 103 slices!
# 0
# Another slice eaten!
# Now eaten 104 slices!
# 0
# Another slice eaten!
# Now eaten 105 slices!
# 0
# Another slice eaten!
# Now eaten 106 slices!
# 0
# Another slice eaten!
# Now eaten 107 slices!
# 0
# Another slice eaten!
# Now eaten 108 slices!
# 0
# Another slice eaten!
# Now eaten 109 slices!
# 0
# Another slice eaten!
# Now eaten 110 slices!
# 0
# Another slice eaten!
# Now eaten 111 slices!
# 0
# Another slice eaten!
# Now eaten 112 slices!
# 0
# Another slice eaten!
# Now eaten 113 slices!
# 0
# Another slice eaten!
# Now eaten 114 slices!
# 0
# Another slice eaten!
# Now eaten 115 slices!
# 0
# Another slice eaten!
# Now eaten 116 slices!
# 0
# Another slice eaten!
# Now eaten 117 slices!
# 0
# Another slice eaten!
# Now eaten 118 slices!
# 0
# Another slice eaten!
# Now eaten 119 slices!
# 0
# Another slice eaten!
# Now eaten 120 slices!
# 0
# Another slice eaten!
# Now eaten 121 slices!
# 0
# Another slice eaten!
# Now eaten 122 slices!
# 0
# Another slice eaten!
# Now eaten 123 slices!
# 0
# Another slice eaten!
# Now eaten 124 slices!
# 0
# Another slice eaten!
# Now eaten 125 slices!
# 0
# Another slice eaten!
# Now eaten 126 slices!
# 0
# Another slice eaten!
# Now eaten 127 slices!
# 0
# Another slice eaten!
# Now eaten 128 slices!
# 0
# Another slice eaten!
# Now eaten 129 slices!
# 0
# Another slice eaten!
# Now eaten 130 slices!
# 0
# Another slice eaten!
# Now eaten 131 slices!
# 0
# Another slice eaten!
# Now eaten 132 slices!
# 0
# Another slice eaten!
# Now eaten 133 slices!
# 0
# Another slice eaten!
# Now eaten 134 slices!
# 0
# Another slice eaten!
# Now eaten 135 slices!
# 0
# Another slice eaten!
# Now eaten 136 slices!
# 0
# Another slice eaten!
# Now eaten 137 slices!
# 0
# Another slice eaten!
# Now eaten 138 slices!
# 0
# Another slice eaten!
# Now eaten 139 slices!
# 0
# Another slice eaten!
# Now eaten 140 slices!
# 0
# Another slice eaten!
# Now eaten 141 slices!
# 0
# Another slice eaten!
# Now eaten 142 slices!
# 0
# Another slice eaten!
# Now eaten 143 slices!
# 0
# Another slice eaten!
# Now eaten 144 slices!
# 0
# Another slice eaten!
# Now eaten 145 slices!
# 0
# Another slice eaten!
# Now eaten 146 slices!
# 0
# Another slice eaten!
# Now eaten 147 slices!
# 0
# Another slice eaten!
# Now eaten 148 slices!
# 0
# Another slice eaten!
# Now eaten 149 slices!
# 0
# Another slice eaten!
# Now eaten 150 slices!
# 0
# Another slice eaten!
# Now eaten 151 slices!
# 0
# Another slice eaten!
# Now eaten 152 slices!
# 0
# Another slice eaten!
# Now eaten 153 slices!
# 0
# Another slice eaten!
# Now eaten 154 slices!
# 0
# Another slice eaten!
# Now eaten 155 slices!
# 0
# Another slice eaten!
# Now eaten 156 slices!
# 0
# Another slice eaten!
# Now eaten 157 slices!
# 0
# Another slice eaten!
# Now eaten 158 slices!
# 0
# Another slice eaten!
# Now eaten 159 slices!
# 0
# Another slice eaten!
# Now eaten 160 slices!
# 0
# Another slice eaten!
# Now eaten 161 slices!
# 0
# Another slice eaten!
# Now eaten 162 slices!
# 0
# Another slice eaten!
# Now eaten 163 slices!
# 0
# Another slice eaten!
# Now eaten 164 slices!
# 0
# Another slice eaten!
# Now eaten 165 slices!
# 0
# Another slice eaten!
# Now eaten 166 slices!
# 0
# Another slice eaten!
# Now eaten 167 slices!
# 0
# Another slice eaten!
# Now eaten 168 slices!
# 0
# Another slice eaten!
# Now eaten 169 slices!
# 0
# Another slice eaten!
# Now eaten 170 slices!
# 0
# Another slice eaten!
# Now eaten 171 slices!
# 0
# Another slice eaten!
# Now eaten 172 slices!
# 0
# Another slice eaten!
# Now eaten 173 slices!
# 0
# Another slice eaten!
# Now eaten 174 slices!
# 0
# Another slice eaten!
# Now eaten 175 slices!
# 0
# Another slice eaten!
# Now eaten 176 slices!
# 0
# Another slice eaten!
# Now eaten 177 slices!
# 0
# Another slice eaten!
# Now eaten 178 slices!
# 0
# Another slice eaten!
# Now eaten 179 slices!
# 0
# Another slice eaten!
# Now eaten 180 slices!
# 0
# Another slice eaten!
# Now eaten 181 slices!
# 0
# Another slice eaten!
# Now eaten 182 slices!
# 0
# Another slice eaten!
# Now eaten 183 slices!
# 0
# Another slice eaten!
# Now eaten 184 slices!
# 0
# Another slice eaten!
# Now eaten 185 slices!
# 0
# Another slice eaten!
# Now eaten 186 slices!
# 0
# Another slice eaten!
# Now eaten 187 slices!
# 0
# Another slice eaten!
# Now eaten 188 slices!
# 0
# Another slice eaten!
# Now eaten 189 slices!
# 0
# Another slice eaten!
# Now eaten 190 slices!
# 0
# Another slice eaten!
# Now eaten 191 slices!
# 0
# Another slice eaten!
# Now eaten 192 slices!
# 0
# Another slice eaten!
# Now eaten 193 slices!
# 0
# Another slice eaten!
# Now eaten 194 slices!
# 0
# Another slice eaten!
# Now eaten 195 slices!
# 0
# Another slice eaten!
# Now eaten 196 slices!
# 0
# Another slice eaten!
# Now eaten 197 slices!
# 0
# Another slice eaten!
# Now eaten 198 slices!
# 0
# Another slice eaten!
# Now eaten 199 slices!
# 0
# Another slice eaten!
# Now eaten 200 slices!
# 0
# Another slice eaten!
# Now eaten 201 slices!
# 0
# Another slice eaten!
# Now eaten 202 slices!
# 0
# Another slice eaten!
# Now eaten 203 slices!
# 0
# Another slice eaten!
# Now eaten 204 slices!
# 0
# Another slice eaten!
# Now eaten 205 slices!
# 0
# Another slice eaten!
# Now eaten 206 slices!
# 0
# Another slice eaten!
# Now eaten 207 slices!
# 0
# Another slice eaten!
# Now eaten 208 slices!
# 0
# Another slice eaten!
# Now eaten 209 slices!
# 0
# Another slice eaten!
# Now eaten 210 slices!
# 0
# Another slice eaten!
# Now eaten 211 slices!
# 0
# Another slice eaten!
# Now eaten 212 slices!
# 0
# Another slice eaten!
# Now eaten 213 slices!
# 0
# Another slice eaten!
# Now eaten 214 slices!
# 0
# Another slice eaten!
# Now eaten 215 slices!
# 0
# Another slice eaten!
# Now eaten 216 slices!
# 0
# Another slice eaten!
# Now eaten 217 slices!
# 0
# Another slice eaten!
# Now eaten 218 slices!
# 0
# Another slice eaten!
# Now eaten 219 slices!
# 0
# Another slice eaten!
# Now eaten 220 slices!
# 0
# Another slice eaten!
# Now eaten 221 slices!
# 0
# Another slice eaten!
# Now eaten 222 slices!
# 0
# Another slice eaten!
# Now eaten 223 slices!
# 0
# Another slice eaten!
# Now eaten 224 slices!
# 0
# Another slice eaten!
# Now eaten 225 slices!
# 0
# Another slice eaten!
# Now eaten 226 slices!
# 0
# Another slice eaten!
# Now eaten 227 slices!
# 0
# Another slice eaten!
# Now eaten 228 slices!
# 0
# Another slice eaten!
# Now eaten 229 slices!
# 0
# Another slice eaten!
# Now eaten 230 slices!
# 0
# Another slice eaten!
# Now eaten 231 slices!
# 0
# Another slice eaten!
# Now eaten 232 slices!
# 0
# Another slice eaten!
# Now eaten 233 slices!
# 0
# Another slice eaten!
# Now eaten 234 slices!
# 0
# Another slice eaten!
# Now eaten 235 slices!
# 0
# Another slice eaten!
# Now eaten 236 slices!
# 0
# Another slice eaten!
# Now eaten 237 slices!
# 0
# Another slice eaten!
# Now eaten 238 slices!
# 0
# Another slice eaten!
# Now eaten 239 slices!
# 0
# Another slice eaten!
# Now eaten 240 slices!
# 0
# Another slice eaten!
# Now eaten 241 slices!
# 0
# Another slice eaten!
# Now eaten 242 slices!
# 0
# Another slice eaten!
# Now eaten 243 slices!
# 0
# Another slice eaten!
# Now eaten 244 slices!
# 0
# Another slice eaten!
# Now eaten 245 slices!
# 0
# Another slice eaten!
# Now eaten 246 slices!
# 0
# Another slice eaten!
# Now eaten 247 slices!
# 0
# Another slice eaten!
# Now eaten 248 slices!
# 0
# Another slice eaten!
# Now eaten 249 slices!
# 0
# Another slice eaten!
# Now eaten 250 slices!
# 0
# Another slice eaten!
# Now eaten 251 slices!
# 0
# Another slice eaten!
# Now eaten 252 slices!
# 0
# Another slice eaten!
# Now eaten 253 slices!
# 0
# Another slice eaten!
# Now eaten 254 slices!
# 0
# Another slice eaten!
# Now eaten 255 slices!
# 0
# Another slice eaten!
# Now eaten 256 slices!
# 0
# Another slice eaten!
# Now eaten 257 slices!
# 0
# Another slice eaten!
# Now eaten 258 slices!
# 0
# Another slice eaten!
# Now eaten 259 slices!
# 0
# Another slice eaten!
# Now eaten 260 slices!
# 0
# Another slice eaten!
# Now eaten 261 slices!
# 0
# Another slice eaten!
# Now eaten 262 slices!
# 0
# Another slice eaten!
# Now eaten 263 slices!
# 0
# Another slice eaten!
# Now eaten 264 slices!
# 0
# Another slice eaten!
# Now eaten 265 slices!
# 0
# Another slice eaten!
# Now eaten 266 slices!
# 0
# Another slice eaten!
# Now eaten 267 slices!
# 0
# Another slice eaten!
# Now eaten 268 slices!
# 0
# Another slice eaten!
# Now eaten 269 slices!
# 0
# Another slice eaten!
# Now eaten 270 slices!
# 0
# Another slice eaten!
# Now eaten 271 slices!
# 0
# Another slice eaten!
# Now eaten 272 slices!
# 0
# Another slice eaten!
# Now eaten 273 slices!
# 0
# Another slice eaten!
# Now eaten 274 slices!
# 0
# Another slice eaten!
# Now eaten 275 slices!
# 0
# Another slice eaten!
# Now eaten 276 slices!
# 0
# Another slice eaten!
# Now eaten 277 slices!
# 0
# Another slice eaten!
# Now eaten 278 slices!
# 0
# Another slice eaten!
# Now eaten 279 slices!
# 0
# Another slice eaten!
# Now eaten 280 slices!
# 0
# Another slice eaten!
# Now eaten 281 slices!
# 0
# Another slice eaten!
# Now eaten 282 slices!
# 0
# Another slice eaten!
# Now eaten 283 slices!
# 0
# Another slice eaten!
# Now eaten 284 slices!
# 0
# Another slice eaten!
# Now eaten 285 slices!
# 0
# Another slice eaten!
# Now eaten 286 slices!
# 0
# Another slice eaten!
# Now eaten 287 slices!
# 0
# Another slice eaten!
# Now eaten 288 slices!
# 0
# Another slice eaten!
# Now eaten 289 slices!
# 0
# Another slice eaten!
# Now eaten 290 slices!
# 0
# Another slice eaten!
# Now eaten 291 slices!
# 0
# Another slice eaten!
# Now eaten 292 slices!
# 0
# Another slice eaten!
# Now eaten 293 slices!
# 0
# Another slice eaten!
# Now eaten 294 slices!
# 0
# Another slice eaten!
# Now eaten 295 slices!
# 0
# Another slice eaten!
# Now eaten 296 slices!
# 0
# Another slice eaten!
# Now eaten 297 slices!
# 0
# Another slice eaten!
# Now eaten 298 slices!
# 0
# Another slice eaten!
# Now eaten 299 slices!
# 0
# Another slice eaten!
# Now eaten 300 slices!
# 0
# Another slice eaten!
# Now eaten 301 slices!
# 0
# Another slice eaten!
# Now eaten 302 slices!
# 0
# Another slice eaten!
# Now eaten 303 slices!
# 0
# Another slice eaten!
# Now eaten 304 slices!
# 0
# Another slice eaten!
# Now eaten 305 slices!
# 0
# Another slice eaten!
# Now eaten 306 slices!
# 0
# Another slice eaten!
# Now eaten 307 slices!
# 0
# Another slice eaten!
# Now eaten 308 slices!
# 0
# Another slice eaten!
# Now eaten 309 slices!
# 0
# Another slice eaten!
# Now eaten 310 slices!
# 0
# Another slice eaten!
# Now eaten 311 slices!
# 0
# Another slice eaten!
# Now eaten 312 slices!
# 0
# Another slice eaten!
# Now eaten 313 slices!
# 0
# Another slice eaten!
# Now eaten 314 slices!
# 0
# Another slice eaten!
# Now eaten 315 slices!
# 0
# Another slice eaten!
# Now eaten 316 slices!
# 0
# Another slice eaten!
# Now eaten 317 slices!
# 0
# Another slice eaten!
# Now eaten 318 slices!
# 0
# Another slice eaten!
# Now eaten 319 slices!
# 0
# Another slice eaten!
# Now eaten 320 slices!
# 0
# Another slice eaten!
# Now eaten 321 slices!
# 0
# Another slice eaten!
# Now eaten 322 slices!
# 0
# Another slice eaten!
# Now eaten 323 slices!
# 0
# Another slice eaten!
# Now eaten 324 slices!
# 0
# Another slice eaten!
# Now eaten 325 slices!
# 0
# Another slice eaten!
# Now eaten 326 slices!
# 0
# Another slice eaten!
# Now eaten 327 slices!
# 0
# Another slice eaten!
# Now eaten 328 slices!
# 0
# Another slice eaten!
# Now eaten 329 slices!
# 0
# Another slice eaten!
# Now eaten 330 slices!
# 0
# Another slice eaten!
# Now eaten 331 slices!
# 0
# Another slice eaten!
# Now eaten 332 slices!
# 0
# Another slice eaten!
# Now eaten 333 slices!
# 0
# Another slice eaten!
# Now eaten 334 slices!
# 0
# Another slice eaten!
# Now eaten 335 slices!
# 0
# Another slice eaten!
# Now eaten 336 slices!
# 0
# Another slice eaten!
# Now eaten 337 slices!
# 0
# Another slice eaten!
# Now eaten 338 slices!
# 0
# Another slice eaten!
# Now eaten 339 slices!
# 0
# Another slice eaten!
# Now eaten 340 slices!
# 0
# Another slice eaten!
# Now eaten 341 slices!
# 0
# Another slice eaten!
# Now eaten 342 slices!
# 0
# Another slice eaten!
# Now eaten 343 slices!
# 0
# Another slice eaten!
# Now eaten 344 slices!
# 0
# Another slice eaten!
# Now eaten 345 slices!
# 0
# Another slice eaten!
# Now eaten 346 slices!
# 0
# Another slice eaten!
# Now eaten 347 slices!
# 0
# Another slice eaten!
# Now eaten 348 slices!
# 0
# Another slice eaten!
# Now eaten 349 slices!
# 0
# Another slice eaten!
# Now eaten 350 slices!
# 0
# Another slice eaten!
# Now eaten 351 slices!
# 0
# Another slice eaten!
# Now eaten 352 slices!
# 0
# Another slice eaten!
# Now eaten 353 slices!
# 0
# Another slice eaten!
# Now eaten 354 slices!
# 0
# Another slice eaten!
# Now eaten 355 slices!
# 0
# Another slice eaten!
# Now eaten 356 slices!
# 0
# Another slice eaten!
# Now eaten 357 slices!
# 0
# Another slice eaten!
# Now eaten 358 slices!
# 0
# Another slice eaten!
# Now eaten 359 slices!
# 0
# Another slice eaten!
# Now eaten 360 slices!
# 0
# Another slice eaten!
# Now eaten 361 slices!
# 0
# Another slice eaten!
# Now eaten 362 slices!
# 0
# Another slice eaten!
# Now eaten 363 slices!
# 0
# Another slice eaten!
# Now eaten 364 slices!
# 0
# Another slice eaten!
# Now eaten 365 slices!
# 0
# Another slice eaten!
# Now eaten 366 slices!
# 0
# Another slice eaten!
# Now eaten 367 slices!
# 0
# Another slice eaten!
# Now eaten 368 slices!
# 0
# Another slice eaten!
# Now eaten 369 slices!
# 0
# Another slice eaten!
# Now eaten 370 slices!
# 0
# Another slice eaten!
# Now eaten 371 slices!
# 0
# Another slice eaten!
# Now eaten 372 slices!
# 0
# Another slice eaten!
# Now eaten 373 slices!
# 0
# Another slice eaten!
# Now eaten 374 slices!
# 0
# Another slice eaten!
# Now eaten 375 slices!
# 0
# Another slice eaten!
# Now eaten 376 slices!
# 0
# Another slice eaten!
# Now eaten 377 slices!
# 0
# Another slice eaten!
# Now eaten 378 slices!
# 0
# Another slice eaten!
# Now eaten 379 slices!
# 0
# Another slice eaten!
# Now eaten 380 slices!
# 0
# Another slice eaten!
# Now eaten 381 slices!
# 0
# Another slice eaten!
# Now eaten 382 slices!
# 0
# Another slice eaten!
# Now eaten 383 slices!
# 0
# Another slice eaten!
# Now eaten 384 slices!
# 0
# Another slice eaten!
# Now eaten 385 slices!
# 0
# Another slice eaten!
# Now eaten 386 slices!
# 0
# Another slice eaten!
# Now eaten 387 slices!
# 0
# Another slice eaten!
# Now eaten 388 slices!
# 0
# Another slice eaten!
# Now eaten 389 slices!
# 0
# Another slice eaten!
# Now eaten 390 slices!
# 0
# Another slice eaten!
# Now eaten 391 slices!
# 0
# Another slice eaten!
# Now eaten 392 slices!
# 0
# Another slice eaten!
# Now eaten 393 slices!
# 0
# Another slice eaten!
# Now eaten 394 slices!
# 0
# Another slice eaten!
# Now eaten 395 slices!
# 0
# Another slice eaten!
# Now eaten 396 slices!
# 0
# Another slice eaten!
# Now eaten 397 slices!
# 0
# Another slice eaten!
# Now eaten 398 slices!
# 0
# Another slice eaten!
# Now eaten 399 slices!
# 0
# Another slice eaten!
# Now eaten 400 slices!
# 0
# Another slice eaten!
# Now eaten 401 slices!
# 0
# Another slice eaten!
# Now eaten 402 slices!
# 0
# Another slice eaten!
# Now eaten 403 slices!
# 0
# Another slice eaten!
# Now eaten 404 slices!
# 0
# Another slice eaten!
# Now eaten 405 slices!
# 0
# Another slice eaten!
# Now eaten 406 slices!
# 0
# Another slice eaten!
# Now eaten 407 slices!
# 0
# Another slice eaten!
# Now eaten 408 slices!
# 0
# Another slice eaten!
# Now eaten 409 slices!
# 0
# Another slice eaten!
# Now eaten 410 slices!
# 0
# Another slice eaten!
# Now eaten 411 slices!
# 0
# Another slice eaten!
# Now eaten 412 slices!
# 0
# Another slice eaten!
# Now eaten 413 slices!
# 0
# Another slice eaten!
# Now eaten 414 slices!
# 0
# Another slice eaten!
# Now eaten 415 slices!
# 0
# Another slice eaten!
# Now eaten 416 slices!
# 0
# Another slice eaten!
# Now eaten 417 slices!
# 0
# Another slice eaten!
# Now eaten 418 slices!
# 0
# Another slice eaten!
# Now eaten 419 slices!
# 0
# Another slice eaten!
# Now eaten 420 slices!
# 0
# Another slice eaten!
# Now eaten 421 slices!
# 0
# Another slice eaten!
# Now eaten 422 slices!
# 0
# Another slice eaten!
# Now eaten 423 slices!
# 0
# Another slice eaten!
# Now eaten 424 slices!
# 0
# Another slice eaten!
# Now eaten 425 slices!
# 0
# Another slice eaten!
# Now eaten 426 slices!
# 0
# Another slice eaten!
# Now eaten 427 slices!
# 0
# Another slice eaten!
# Now eaten 428 slices!
# 0
# Another slice eaten!
# Now eaten 429 slices!
# 0
# Another slice eaten!
# Now eaten 430 slices!
# 0
# Another slice eaten!
# Now eaten 431 slices!
# 0
# Another slice eaten!
# Now eaten 432 slices!
# 0
# Another slice eaten!
# Now eaten 433 slices!
# 0
# Another slice eaten!
# Now eaten 434 slices!
# 0
# Another slice eaten!
# Now eaten 435 slices!
# 0
# Another slice eaten!
# Now eaten 436 slices!
# 0
# Another slice eaten!
# Now eaten 437 slices!
# 0
# Another slice eaten!
# Now eaten 438 slices!
# 0
# Another slice eaten!
# Now eaten 439 slices!
# 0
# Another slice eaten!
# Now eaten 440 slices!
# 0
# Another slice eaten!
# Now eaten 441 slices!
# 0
# Another slice eaten!
# Now eaten 442 slices!
# 0
# Another slice eaten!
# Now eaten 443 slices!
# 0
# Another slice eaten!
# Now eaten 444 slices!
# 0
# Another slice eaten!
# Now eaten 445 slices!
# 0
# Another slice eaten!
# Now eaten 446 slices!
# 0
# Another slice eaten!
# Now eaten 447 slices!
# 0
# Another slice eaten!
# Now eaten 448 slices!
# 0
# Another slice eaten!
# Now eaten 449 slices!
# 0
# Another slice eaten!
# Now eaten 450 slices!
# 0
# Another slice eaten!
# Now eaten 451 slices!
# 0
# Another slice eaten!
# Now eaten 452 slices!
# 0
# Another slice eaten!
# Now eaten 453 slices!
# 0
# Another slice eaten!
# Now eaten 454 slices!
# 0
# Another slice eaten!
# Now eaten 455 slices!
# 0
# Another slice eaten!
# Now eaten 456 slices!
# 0
# Another slice eaten!
# Now eaten 457 slices!
# 0
# Another slice eaten!
# Now eaten 458 slices!
# 0
# Another slice eaten!
# Now eaten 459 slices!
# 0
# Another slice eaten!
# Now eaten 460 slices!
# 0
# Another slice eaten!
# Now eaten 461 slices!
# 0
# Another slice eaten!
# Now eaten 462 slices!
# 0
# Another slice eaten!
# Now eaten 463 slices!
# 0
# Another slice eaten!
# Now eaten 464 slices!
# 0
# Another slice eaten!
# Now eaten 465 slices!
# 0
# Another slice eaten!
# Now eaten 466 slices!
# 0
# Another slice eaten!
# Now eaten 467 slices!
# 0
# Another slice eaten!
# Now eaten 468 slices!
# 0
# Another slice eaten!
# Now eaten 469 slices!
# 0
# Another slice eaten!
# Now eaten 470 slices!
# 0
# Another slice eaten!
# Now eaten 471 slices!
# 0
# Another slice eaten!
# Now eaten 472 slices!
# 0
# Another slice eaten!
# Now eaten 473 slices!
# 0
# Another slice eaten!
# Now eaten 474 slices!
# 0
# Another slice eaten!
# Now eaten 475 slices!
# 0
# Another slice eaten!
# Now eaten 476 slices!
# 0
# Another slice eaten!
# Now eaten 477 slices!
# 0
# Another slice eaten!
# Now eaten 478 slices!
# 0
# Another slice eaten!
# Now eaten 479 slices!
# 0
# Another slice eaten!
# Now eaten 480 slices!
# 0
# Another slice eaten!
# Now eaten 481 slices!
# 0
# Another slice eaten!
# Now eaten 482 slices!
# 0
# Another slice eaten!
# Now eaten 483 slices!
# 0
# Another slice eaten!
# Now eaten 484 slices!
# 0
# Another slice eaten!
# Now eaten 485 slices!
# 0
# Another slice eaten!
# Now eaten 486 slices!
# 0
# Another slice eaten!
# Now eaten 487 slices!
# 0
# Another slice eaten!
# Now eaten 488 slices!
# 0
# Another slice eaten!
# Now eaten 489 slices!
# 0
# Another slice eaten!
# Now eaten 490 slices!
# 0
# Another slice eaten!
# Now eaten 491 slices!
# 0
# Another slice eaten!
# Now eaten 492 slices!
# 0
# Another slice eaten!
# Now eaten 493 slices!
# 0
# Another slice eaten!
# Now eaten 494 slices!
# 0
# Another slice eaten!
# Now eaten 495 slices!
# 0
# Another slice eaten!
# Now eaten 496 slices!
# 0
# Another slice eaten!
# Now eaten 497 slices!
# 0
# Another slice eaten!
# Now eaten 498 slices!
# 0
# Another slice eaten!
# Now eaten 499 slices!
# 0
# Another slice eaten!
# Now eaten 500 slices!
# 0
# Another slice eaten!
# Now eaten 501 slices!
# 0
# Another slice eaten!
# Now eaten 502 slices!
# 0
# Another slice eaten!
# Now eaten 503 slices!
# 0
# Another slice eaten!
# Now eaten 504 slices!
# 0
# Another slice eaten!
# Now eaten 505 slices!
# 0
# Another slice eaten!
# Now eaten 506 slices!
# 0
# Another slice eaten!
# Now eaten 507 slices!
# 0
# Another slice eaten!
# Now eaten 508 slices!
# 0
# Another slice eaten!
# Now eaten 509 slices!
# 0
# Another slice eaten!
# Now eaten 510 slices!
# 0
# Another slice eaten!
# Now eaten 511 slices!
# 0
# Another slice eaten!
# Now eaten 512 slices!
# 0
# Another slice eaten!
# Now eaten 513 slices!
# 0
# Another slice eaten!
# Now eaten 514 slices!
# 0
# Another slice eaten!
# Now eaten 515 slices!
# 0
# Another slice eaten!
# Now eaten 516 slices!
# 0
# Another slice eaten!
# Now eaten 517 slices!
# 0
# Another slice eaten!
# Now eaten 518 slices!
# 0
# Another slice eaten!
# Now eaten 519 slices!
# 0
# Another slice eaten!
# Now eaten 520 slices!
# 0
# Another slice eaten!
# Now eaten 521 slices!
# 0
# Another slice eaten!
# Now eaten 522 slices!
# 0
# Another slice eaten!
# Now eaten 523 slices!
# 0
# Another slice eaten!
# Now eaten 524 slices!
# 0
# Another slice eaten!
# Now eaten 525 slices!
# 0
# Another slice eaten!
# Now eaten 526 slices!
# 0
# Another slice eaten!
# Now eaten 527 slices!
# 0
# Another slice eaten!
# Now eaten 528 slices!
# 0
# Another slice eaten!
# Now eaten 529 slices!
# 0
# Another slice eaten!
# Now eaten 530 slices!
# 0
# Another slice eaten!
# Now eaten 531 slices!
# 0
# Another slice eaten!
# Now eaten 532 slices!
# 0
# Another slice eaten!
# Now eaten 533 slices!
# 0
# Another slice eaten!
# Now eaten 534 slices!
# 0
# Another slice eaten!
# Now eaten 535 slices!
# 0
# Another slice eaten!
# Now eaten 536 slices!
# 0
# Another slice eaten!
# Now eaten 537 slices!
# 0
# Another slice eaten!
# Now eaten 538 slices!
# 0
# Another slice eaten!
# Now eaten 539 slices!
# 0
# Another slice eaten!
# Now eaten 540 slices!
# 0
# Another slice eaten!
# Now eaten 541 slices!
# 0
# Another slice eaten!
# Now eaten 542 slices!
# 0
# Another slice eaten!
# Now eaten 543 slices!
# 0
# Another slice eaten!
# Now eaten 544 slices!
# 0
# Another slice eaten!
# Now eaten 545 slices!
# 0
# Another slice eaten!
# Now eaten 546 slices!
# 0
# Another slice eaten!
# Now eaten 547 slices!
# 0
# Another slice eaten!
# Now eaten 548 slices!
# 0
# Another slice eaten!
# Now eaten 549 slices!
# 0
# Another slice eaten!
# Now eaten 550 slices!
# 0
# Another slice eaten!
# Now eaten 551 slices!
# 0
# Another slice eaten!
# Now eaten 552 slices!
# 0
# Another slice eaten!
# Now eaten 553 slices!
# 0
# Another slice eaten!
# Now eaten 554 slices!
# 0
# Another slice eaten!
# Now eaten 555 slices!
# 0
# Another slice eaten!
# Now eaten 556 slices!
# 0
# Another slice eaten!
# Now eaten 557 slices!
# 0
# Another slice eaten!
# Now eaten 558 slices!
# 0
# Another slice eaten!
# Now eaten 559 slices!
# 0
# Another slice eaten!
# Now eaten 560 slices!
# 0
# Another slice eaten!
# Now eaten 561 slices!
# 0
# Another slice eaten!
# Now eaten 562 slices!
# 0
# Another slice eaten!
# Now eaten 563 slices!
# 0
# Another slice eaten!
# Now eaten 564 slices!
# 0
# Another slice eaten!
# Now eaten 565 slices!
# 0
# Another slice eaten!
# Now eaten 566 slices!
# 0
# Another slice eaten!
# Now eaten 567 slices!
# 0
# Another slice eaten!
# Now eaten 568 slices!
# 0
# Another slice eaten!
# Now eaten 569 slices!
# 0
# Another slice eaten!
# Now eaten 570 slices!
# 0
# Another slice eaten!
# Now eaten 571 slices!
# 0
# Another slice eaten!
# Now eaten 572 slices!
# 0
# Another slice eaten!
# Now eaten 573 slices!
# 0
# Another slice eaten!
# Now eaten 574 slices!
# 0
# Another slice eaten!
# Now eaten 575 slices!
# 0
# Another slice eaten!
# Now eaten 576 slices!
# 0
# Another slice eaten!
# Now eaten 577 slices!
# 0
# Another slice eaten!
# Now eaten 578 slices!
# 0
# Another slice eaten!
# Now eaten 579 slices!
# 0
# Another slice eaten!
# Now eaten 580 slices!
# 0
# Another slice eaten!
# Now eaten 581 slices!
# 0
# Another slice eaten!
# Now eaten 582 slices!
# 0
# Another slice eaten!
# Now eaten 583 slices!
# 0
# Another slice eaten!
# Now eaten 584 slices!
# 0
# Another slice eaten!
# Now eaten 585 slices!
# 0
# Another slice eaten!
# Now eaten 586 slices!
# 0
# Another slice eaten!
# Now eaten 587 slices!
# 0
# Another slice eaten!
# Now eaten 588 slices!
# 0
# Another slice eaten!
# Now eaten 589 slices!
# 0
# Another slice eaten!
# Now eaten 590 slices!
# 0
# Another slice eaten!
# Now eaten 591 slices!
# 0
# Another slice eaten!
# Now eaten 592 slices!
# 0
# Another slice eaten!
# Now eaten 593 slices!
# 0
# Another slice eaten!
# Now eaten 594 slices!
# 0
# Another slice eaten!
# Now eaten 595 slices!
# 0
# Another slice eaten!
# Now eaten 596 slices!
# 0
# Another slice eaten!
# Now eaten 597 slices!
# 0
# Another slice eaten!
# Now eaten 598 slices!
# 0
# Another slice eaten!
# Now eaten 599 slices!
# 0
# Another slice eaten!
# Now eaten 600 slices!
# 0
# Another slice eaten!
# Now eaten 601 slices!
# 0
# Another slice eaten!
# Now eaten 602 slices!
# 0
# Another slice eaten!
# Now eaten 603 slices!
# 0
# Another slice eaten!
# Now eaten 604 slices!
# 0
# Another slice eaten!
# Now eaten 605 slices!
# 0
# Another slice eaten!
# Now eaten 606 slices!
# 0
# Another slice eaten!
# Now eaten 607 slices!
# 0
# Another slice eaten!
# Now eaten 608 slices!
# 0
# Another slice eaten!
# Now eaten 609 slices!
# 0
# Another slice eaten!
# Now eaten 610 slices!
# 0
# Another slice eaten!
# Now eaten 611 slices!
# 0
# Another slice eaten!
# Now eaten 612 slices!
# 0
# Another slice eaten!
# Now eaten 613 slices!
# 0
# Another slice eaten!
# Now eaten 614 slices!
# 0
# Another slice eaten!
# Now eaten 615 slices!
# 0
# Another slice eaten!
# Now eaten 616 slices!
# 0
# Another slice eaten!
# Now eaten 617 slices!
# 0
# Another slice eaten!
# Now eaten 618 slices!
# 0
# Another slice eaten!
# Now eaten 619 slices!
# 0
# Another slice eaten!
# Now eaten 620 slices!
# 0
# Another slice eaten!
# Now eaten 621 slices!
# 0
# Another slice eaten!
# Now eaten 622 slices!
# 0
# Another slice eaten!
# Now eaten 623 slices!
# 0
# Another slice eaten!
# Now eaten 624 slices!
# 0
# Another slice eaten!
# Now eaten 625 slices!
# 0
# Another slice eaten!
# Now eaten 626 slices!
# 0
# Another slice eaten!
# Now eaten 627 slices!
# 0
# Another slice eaten!
# Now eaten 628 slices!
# 0
# Another slice eaten!
# Now eaten 629 slices!
# 0
# Another slice eaten!
# Now eaten 630 slices!
# 0
# Another slice eaten!
# Now eaten 631 slices!
# 0
# Another slice eaten!
# Now eaten 632 slices!
# 0
# Another slice eaten!
# Now eaten 633 slices!
# 0
# Another slice eaten!
# Now eaten 634 slices!
# 0
# Another slice eaten!
# Now eaten 635 slices!
# 0
# Another slice eaten!
# Now eaten 636 slices!
# 0
# Another slice eaten!
# Now eaten 637 slices!
# 0
# Another slice eaten!
# Now eaten 638 slices!
# 0
# Another slice eaten!
# Now eaten 639 slices!
# 0
# Another slice eaten!
# Now eaten 640 slices!
# 0
# Another slice eaten!
# Now eaten 641 slices!
# 0
# Another slice eaten!
# Now eaten 642 slices!
# 0
# Another slice eaten!
# Now eaten 643 slices!
# 0
# Another slice eaten!
# Now eaten 644 slices!
# 0
# Another slice eaten!
# Now eaten 645 slices!
# 0
# Another slice eaten!
# Now eaten 646 slices!
# 0
# Another slice eaten!
# Now eaten 647 slices!
# 0
# Another slice eaten!
# Now eaten 648 slices!
# 0
# Another slice eaten!
# Now eaten 649 slices!
# 0
# Another slice eaten!
# Now eaten 650 slices!
# 0
# Another slice eaten!
# Now eaten 651 slices!
# 0
# Another slice eaten!
# Now eaten 652 slices!
# 0
# Another slice eaten!
# Now eaten 653 slices!
# 0
# Another slice eaten!
# Now eaten 654 slices!
# 0
# Another slice eaten!
# Now eaten 655 slices!
# 0
# Another slice eaten!
# Now eaten 656 slices!
# 0
# Another slice eaten!
# Now eaten 657 slices!
# 0
# Another slice eaten!
# Now eaten 658 slices!
# 0
# Another slice eaten!
# Now eaten 659 slices!
# 0
# Another slice eaten!
# Now eaten 660 slices!
# 0
# Another slice eaten!
# Now eaten 661 slices!
# 0
# Another slice eaten!
# Now eaten 662 slices!
# 0
# Another slice eaten!
# Now eaten 663 slices!
# 0
# Another slice eaten!
# Now eaten 664 slices!
# 0
# Another slice eaten!
# Now eaten 665 slices!
# 0
# Another slice eaten!
# Now eaten 666 slices!
# 0
# Another slice eaten!
# Now eaten 667 slices!
# 0
# Another slice eaten!
# Now eaten 668 slices!
# 0
# Another slice eaten!
# Now eaten 669 slices!
# 0
# Another slice eaten!
# Now eaten 670 slices!
# 0
# Another slice eaten!
# Now eaten 671 slices!
# 0
# Another slice eaten!
# Now eaten 672 slices!
# 0
# Another slice eaten!
# Now eaten 673 slices!
# 0
# Another slice eaten!
# Now eaten 674 slices!
# 0
# Another slice eaten!
# Now eaten 675 slices!
# 0
# Another slice eaten!
# Now eaten 676 slices!
# 0
# Another slice eaten!
# Now eaten 677 slices!
# 0
# Another slice eaten!
# Now eaten 678 slices!
# 0
# Another slice eaten!
# Now eaten 679 slices!
# 0
# Another slice eaten!
# Now eaten 680 slices!
# 0
# Another slice eaten!
# Now eaten 681 slices!
# 0
# Another slice eaten!
# Now eaten 682 slices!
# 0
# Another slice eaten!
# Now eaten 683 slices!
# 0
# Another slice eaten!
# Now eaten 684 slices!
# 0
# Another slice eaten!
# Now eaten 685 slices!
# 0
# Another slice eaten!
# Now eaten 686 slices!
# 0
# Another slice eaten!
# Now eaten 687 slices!
# 0
# Another slice eaten!
# Now eaten 688 slices!
# 0
# Another slice eaten!
# Now eaten 689 slices!
# 0
# Another slice eaten!
# Now eaten 690 slices!
# 0
# Another slice eaten!
# Now eaten 691 slices!
# 0
# Another slice eaten!
# Now eaten 692 slices!
# 0
# Another slice eaten!
# Now eaten 693 slices!
# 0
# Another slice eaten!
# Now eaten 694 slices!
# 0
# Another slice eaten!
# Now eaten 695 slices!
# 0
# Another slice eaten!
# Now eaten 696 slices!
# 0
# Another slice eaten!
# Now eaten 697 slices!
# 0
# Another slice eaten!
# Now eaten 698 slices!
# 0
# Another slice eaten!
# Now eaten 699 slices!
# 0
# Another slice eaten!
# Now eaten 700 slices!
# 0
# Another slice eaten!
# Now eaten 701 slices!
# 0
# Another slice eaten!
# Now eaten 702 slices!
# 0
# Another slice eaten!
# Now eaten 703 slices!
# 0
# Another slice eaten!
# Now eaten 704 slices!
# 0
# Another slice eaten!
# Now eaten 705 slices!
# 0
# Another slice eaten!
# Now eaten 706 slices!
# 0
# Another slice eaten!
# Now eaten 707 slices!
# 0
# Another slice eaten!
# Now eaten 708 slices!
# 0
# Another slice eaten!
# Now eaten 709 slices!
# 0
# Another slice eaten!
# Now eaten 710 slices!
# 0
# Another slice eaten!
# Now eaten 711 slices!
# 0
# Another slice eaten!
# Now eaten 712 slices!
# 0
# Another slice eaten!
# Now eaten 713 slices!
# 0
# Another slice eaten!
# Now eaten 714 slices!
# 0
# Another slice eaten!
# Now eaten 715 slices!
# 0
# Another slice eaten!
# Now eaten 716 slices!
# 0
# Another slice eaten!
# Now eaten 717 slices!
# 0
# Another slice eaten!
# Now eaten 718 slices!
# 0
# Another slice eaten!
# Now eaten 719 slices!
# 0
# Another slice eaten!
# Now eaten 720 slices!
# 0
# Another slice eaten!
# Now eaten 721 slices!
# 0
# Another slice eaten!
# Now eaten 722 slices!
# 0
# Another slice eaten!
# Now eaten 723 slices!
# 0
# Another slice eaten!
# Now eaten 724 slices!
# 0
# Another slice eaten!
# Now eaten 725 slices!
# 0
# Another slice eaten!
# Now eaten 726 slices!
# 0
# Another slice eaten!
# Now eaten 727 slices!
# 0
# Another slice eaten!
# Now eaten 728 slices!
# 0
# Another slice eaten!
# Now eaten 729 slices!
# 0
# Another slice eaten!
# Now eaten 730 slices!
# 0
# Another slice eaten!
# Now eaten 731 slices!
# 0
# Another slice eaten!
# Now eaten 732 slices!
# 0
# Another slice eaten!
# Now eaten 733 slices!
# 0
# Another slice eaten!
# Now eaten 734 slices!
# 0
# Another slice eaten!
# Now eaten 735 slices!
# 0
# Another slice eaten!
# Now eaten 736 slices!
# 0
# Another slice eaten!
# Now eaten 737 slices!
# 0
# Another slice eaten!
# Now eaten 738 slices!
# 0
# Another slice eaten!
# Now eaten 739 slices!
# 0
# Another slice eaten!
# Now eaten 740 slices!
# 0
# Another slice eaten!
# Now eaten 741 slices!
# 0
# Another slice eaten!
# Now eaten 742 slices!
# 0
# Another slice eaten!
# Now eaten 743 slices!
# 0
# Another slice eaten!
# Now eaten 744 slices!
# 0
# Another slice eaten!
# Now eaten 745 slices!
# 0
# Another slice eaten!
# Now eaten 746 slices!
# 0
# Another slice eaten!
# Now eaten 747 slices!
# 0
# Another slice eaten!
# Now eaten 748 slices!
# 0
# Another slice eaten!
# Now eaten 749 slices!
# 0
# Another slice eaten!
# Now eaten 750 slices!
# 0
# Another slice eaten!
# Now eaten 751 slices!
# 0
# Another slice eaten!
# Now eaten 752 slices!
# 0
# Another slice eaten!
# Now eaten 753 slices!
# 0
# Another slice eaten!
# Now eaten 754 slices!
# 0
# Another slice eaten!
# Now eaten 755 slices!
# 0
# Another slice eaten!
# Now eaten 756 slices!
# 0
# Another slice eaten!
# Now eaten 757 slices!
# 0
# Another slice eaten!
# Now eaten 758 slices!
# 0
# Another slice eaten!
# Now eaten 759 slices!
# 0
# Another slice eaten!
# Now eaten 760 slices!
# 0
# Another slice eaten!
# Now eaten 761 slices!
# 0
# Another slice eaten!
# Now eaten 762 slices!
# 0
# Another slice eaten!
# Now eaten 763 slices!
# 0
# Another slice eaten!
# Now eaten 764 slices!
# 0
# Another slice eaten!
# Now eaten 765 slices!
# 0
# Another slice eaten!
# Now eaten 766 slices!
# 0
# Another slice eaten!
# Now eaten 767 slices!
# 0
# Another slice eaten!
# Now eaten 768 slices!
# 0
# Another slice eaten!
# Now eaten 769 slices!
# 0
# Another slice eaten!
# Now eaten 770 slices!
# 0
# Another slice eaten!
# Now eaten 771 slices!
# 0
# Another slice eaten!
# Now eaten 772 slices!
# 0
# Another slice eaten!
# Now eaten 773 slices!
# 0
# Another slice eaten!
# Now eaten 774 slices!
# 0
# Another slice eaten!
# Now eaten 775 slices!
# 0
# Another slice eaten!
# Now eaten 776 slices!
# 0
# Another slice eaten!
# Now eaten 777 slices!
# 0
# Another slice eaten!
# Now eaten 778 slices!
# 0
# Another slice eaten!
# Now eaten 779 slices!
# 0
# Another slice eaten!
# Now eaten 780 slices!
# 0
# Another slice eaten!
# Now eaten 781 slices!
# 0
# Another slice eaten!
# Now eaten 782 slices!
# 0
# Another slice eaten!
# Now eaten 783 slices!
# 0
# Another slice eaten!
# Now eaten 784 slices!
# 0
# Another slice eaten!
# Now eaten 785 slices!
# 0
# Another slice eaten!
# Now eaten 786 slices!
# 0
# Another slice eaten!
# Now eaten 787 slices!
# 0
# Another slice eaten!
# Now eaten 788 slices!
# 0
# Another slice eaten!
# Now eaten 789 slices!
# 0
# Another slice eaten!
# Now eaten 790 slices!
# 0
# Another slice eaten!
# Now eaten 791 slices!
# 0
# Another slice eaten!
# Now eaten 792 slices!
# 0
# Another slice eaten!
# Now eaten 793 slices!
# 0
# Another slice eaten!
# Now eaten 794 slices!
# 0
# Another slice eaten!
# Now eaten 795 slices!
# 0
# Another slice eaten!
# Now eaten 796 slices!
# 0
# Another slice eaten!
# Now eaten 797 slices!
# 0
# Another slice eaten!
# Now eaten 798 slices!
# 0
# Another slice eaten!
# Now eaten 799 slices!
# 0
# Another slice eaten!
# Now eaten 800 slices!
# 0
# Another slice eaten!
# Now eaten 801 slices!
# 0
# Another slice eaten!
# Now eaten 802 slices!
# 0
# Another slice eaten!
# Now eaten 803 slices!
# 0
# Another slice eaten!
# Now eaten 804 slices!
# 0
# Another slice eaten!
# Now eaten 805 slices!
# 0
# Another slice eaten!
# Now eaten 806 slices!
# 0
# Another slice eaten!
# Now eaten 807 slices!
# 0
# Another slice eaten!
# Now eaten 808 slices!
# 0
# Another slice eaten!
# Now eaten 809 slices!
# 0
# Another slice eaten!
# Now eaten 810 slices!
# 0
# Another slice eaten!
# Now eaten 811 slices!
# 0
# Another slice eaten!
# Now eaten 812 slices!
# 0
# Another slice eaten!
# Now eaten 813 slices!
# 0
# Another slice eaten!
# Now eaten 814 slices!
# 0
# Another slice eaten!
# Now eaten 815 slices!
# 0
# Another slice eaten!
# Now eaten 816 slices!
# 0
# Another slice eaten!
# Now eaten 817 slices!
# 0
# Another slice eaten!
# Now eaten 818 slices!
# 0
# Another slice eaten!
# Now eaten 819 slices!
# 0
# Another slice eaten!
# Now eaten 820 slices!
# 0
# Another slice eaten!
# Now eaten 821 slices!
# 0
# Another slice eaten!
# Now eaten 822 slices!
# 0
# Another slice eaten!
# Now eaten 823 slices!
# 0
# Another slice eaten!
# Now eaten 824 slices!
# 0
# Another slice eaten!
# Now eaten 825 slices!
# 0
# Another slice eaten!
# Now eaten 826 slices!
# 0
# Another slice eaten!
# Now eaten 827 slices!
# 0
# Another slice eaten!
# Now eaten 828 slices!
# 0
# Another slice eaten!
# Now eaten 829 slices!
# 0
# Another slice eaten!
# Now eaten 830 slices!
# 0
# Another slice eaten!
# Now eaten 831 slices!
# 0
# Another slice eaten!
# Now eaten 832 slices!
# 0
# Another slice eaten!
# Now eaten 833 slices!
# 0
# Another slice eaten!
# Now eaten 834 slices!
# 0
# Another slice eaten!
# Now eaten 835 slices!
# 0
# Another slice eaten!
# Now eaten 836 slices!
# 0
# Another slice eaten!
# Now eaten 837 slices!
# 0
# Another slice eaten!
# Now eaten 838 slices!
# 0
# Another slice eaten!
# Now eaten 839 slices!
# 0
# Another slice eaten!
# Now eaten 840 slices!
# 0
# Another slice eaten!
# Now eaten 841 slices!
# 0
# Another slice eaten!
# Now eaten 842 slices!
# 0
# Another slice eaten!
# Now eaten 843 slices!
# 0
# Another slice eaten!
# Now eaten 844 slices!
# 0
# Another slice eaten!
# Now eaten 845 slices!
# 0
# Another slice eaten!
# Now eaten 846 slices!
# 0
# Another slice eaten!
# Now eaten 847 slices!
# 0
# Another slice eaten!
# Now eaten 848 slices!
# 0
# Another slice eaten!
# Now eaten 849 slices!
# 0
# Another slice eaten!
# Now eaten 850 slices!
# 0
# Another slice eaten!
# Now eaten 851 slices!
# 0
# Another slice eaten!
# Now eaten 852 slices!
# 0
# Another slice eaten!
# Now eaten 853 slices!
# 0
# Another slice eaten!
# Now eaten 854 slices!
# 0
# Another slice eaten!
# Now eaten 855 slices!
# 0
# Another slice eaten!
# Now eaten 856 slices!
# 0
# Another slice eaten!
# Now eaten 857 slices!
# 0
# Another slice eaten!
# Now eaten 858 slices!
# 0
# Another slice eaten!
# Now eaten 859 slices!
# 0
# Another slice eaten!
# Now eaten 860 slices!
# 0
# Another slice eaten!
# Now eaten 861 slices!
# 0
# Another slice eaten!
# Now eaten 862 slices!
# 0
# Another slice eaten!
# Now eaten 863 slices!
# 0
# Another slice eaten!
# Now eaten 864 slices!
# 0
# Another slice eaten!
# Now eaten 865 slices!
# 0
# Another slice eaten!
# Now eaten 866 slices!
# 0
# Another slice eaten!
# Now eaten 867 slices!
# 0
# Another slice eaten!
# Now eaten 868 slices!
# 0
# Another slice eaten!
# Now eaten 869 slices!
# 0
# Another slice eaten!
# Now eaten 870 slices!
# 0
# Another slice eaten!
# Now eaten 871 slices!
# 0
# Another slice eaten!
# Now eaten 872 slices!
# 0
# Another slice eaten!
# Now eaten 873 slices!
# 0
# Another slice eaten!
# Now eaten 874 slices!
# 0
# Another slice eaten!
# Now eaten 875 slices!
# 0
# Another slice eaten!
# Now eaten 876 slices!
# 0
# Another slice eaten!
# Now eaten 877 slices!
# 0
# Another slice eaten!
# Now eaten 878 slices!
# 0
# Another slice eaten!
# Now eaten 879 slices!
# 0
# Another slice eaten!
# Now eaten 880 slices!
# 0
# Another slice eaten!
# Now eaten 881 slices!
# 0
# Another slice eaten!
# Now eaten 882 slices!
# 0
# Another slice eaten!
# Now eaten 883 slices!
# 0
# Another slice eaten!
# Now eaten 884 slices!
# 0
# Another slice eaten!
# Now eaten 885 slices!
# 0
# Another slice eaten!
# Now eaten 886 slices!
# 0
# Another slice eaten!
# Now eaten 887 slices!
# 0
# Another slice eaten!
# Now eaten 888 slices!
# 0
# Another slice eaten!
# Now eaten 889 slices!
# 0
# Another slice eaten!
# Now eaten 890 slices!
# 0
# Another slice eaten!
# Now eaten 891 slices!
# 0
# Another slice eaten!
# Now eaten 892 slices!
# 0
# Another slice eaten!
# Now eaten 893 slices!
# 0
# Another slice eaten!
# Now eaten 894 slices!
# 0
# Another slice eaten!
# Now eaten 895 slices!
# 0
# Another slice eaten!
# Now eaten 896 slices!
# 0
# Another slice eaten!
# Now eaten 897 slices!
# 0
# Another slice eaten!
# Now eaten 898 slices!
# 0
# Another slice eaten!
# Now eaten 899 slices!
# 0
# Another slice eaten!
# Now eaten 900 slices!
# 0
# Another slice eaten!
# Now eaten 901 slices!
# 0
# Another slice eaten!
# Now eaten 902 slices!
# 0
# Another slice eaten!
# Now eaten 903 slices!
# 0
# Another slice eaten!
# Now eaten 904 slices!
# 0
# Another slice eaten!
# Now eaten 905 slices!
# 0
# Another slice eaten!
# Now eaten 906 slices!
# 0
# Another slice eaten!
# Now eaten 907 slices!
# 0
# Another slice eaten!
# Now eaten 908 slices!
# 0
# Another slice eaten!
# Now eaten 909 slices!
# 0
# Another slice eaten!
# Now eaten 910 slices!
# 0
# Another slice eaten!
# Now eaten 911 slices!
# 0
# Another slice eaten!
# Now eaten 912 slices!
# 0
# Another slice eaten!
# Now eaten 913 slices!
# 0
# Another slice eaten!
# Now eaten 914 slices!
# 0
# Another slice eaten!
# Now eaten 915 slices!
# 0
# Another slice eaten!
# Now eaten 916 slices!
# 0
# Another slice eaten!
# Now eaten 917 slices!
# 0
# Another slice eaten!
# Now eaten 918 slices!
# 0
# Another slice eaten!
# Now eaten 919 slices!
# 0
# Another slice eaten!
# Now eaten 920 slices!
# 0
# Another slice eaten!
# Now eaten 921 slices!
# 0
# Another slice eaten!
# Now eaten 922 slices!
# 0
# Another slice eaten!
# Now eaten 923 slices!
# 0
# Another slice eaten!
# Now eaten 924 slices!
# 0
# Another slice eaten!
# Now eaten 925 slices!
# 0
# Another slice eaten!
# Now eaten 926 slices!
# 0
# Another slice eaten!
# Now eaten 927 slices!
# 0
# Another slice eaten!
# Now eaten 928 slices!
# 0
# Another slice eaten!
# Now eaten 929 slices!
# 0
# Another slice eaten!
# Now eaten 930 slices!
# 0
# Another slice eaten!
# Now eaten 931 slices!
# 0
# Another slice eaten!
# Now eaten 932 slices!
# 0
# Another slice eaten!
# Now eaten 933 slices!
# 0
# Another slice eaten!
# Now eaten 934 slices!
# 0
# Another slice eaten!
# Now eaten 935 slices!
# 0
# Another slice eaten!
# Now eaten 936 slices!
# 0
# Another slice eaten!
# Now eaten 937 slices!
# 0
# Another slice eaten!
# Now eaten 938 slices!
# 0
# Another slice eaten!
# Now eaten 939 slices!
# 0
# Another slice eaten!
# Now eaten 940 slices!
# 0
# Another slice eaten!
# Now eaten 941 slices!
# 0
# Another slice eaten!
# Now eaten 942 slices!
# 0
# Another slice eaten!
# Now eaten 943 slices!
# 0
# Another slice eaten!
# Now eaten 944 slices!
# 0
# Another slice eaten!
# Now eaten 945 slices!
# 0
# Another slice eaten!
# Now eaten 946 slices!
# 0
# Another slice eaten!
# Now eaten 947 slices!
# 0
# Another slice eaten!
# Now eaten 948 slices!
# 0
# Another slice eaten!
# Now eaten 949 slices!
# 0
# Another slice eaten!
# Now eaten 950 slices!
# 0
# Another slice eaten!
# Now eaten 951 slices!
# 0
# Another slice eaten!
# Now eaten 952 slices!
# 0
# Another slice eaten!
# Now eaten 953 slices!
# 0
# Another slice eaten!
# Now eaten 954 slices!
# 0
# Another slice eaten!
# Now eaten 955 slices!
# 0
# Another slice eaten!
# Now eaten 956 slices!
# 0
# Another slice eaten!
# Now eaten 957 slices!
# 0
# Another slice eaten!
# Now eaten 958 slices!
# 0
# Another slice eaten!
# Now eaten 959 slices!
# 0
# Another slice eaten!
# Now eaten 960 slices!
# 0
# Another slice eaten!
# Now eaten 961 slices!
# 0
# Another slice eaten!
# Now eaten 962 slices!
# 0
# Another slice eaten!
# Now eaten 963 slices!
# 0
# Another slice eaten!
# Now eaten 964 slices!
# 0
# Another slice eaten!
# Now eaten 965 slices!
# 0
# Another slice eaten!
# Now eaten 966 slices!
# 0
# Another slice eaten!
# Now eaten 967 slices!
# 0
# Another slice eaten!
# Now eaten 968 slices!
# 0
# Another slice eaten!
# Now eaten 969 slices!
# 0
# Another slice eaten!
# Now eaten 970 slices!
# 0
# Another slice eaten!
# Now eaten 971 slices!
# 0
# Another slice eaten!
# Now eaten 972 slices!
# 0
# Another slice eaten!
# Now eaten 973 slices!
# 0
# Another slice eaten!
# Now eaten 974 slices!
# 0
# Another slice eaten!
# Now eaten 975 slices!
# 0
# Another slice eaten!
# Now eaten 976 slices!
# 0
# Another slice eaten!
# Now eaten 977 slices!
# 0
# Another slice eaten!
# Now eaten 978 slices!
# 0
# Another slice eaten!
# Now eaten 979 slices!
# 0
# Another slice eaten!
# Now eaten 980 slices!
# 0
# Another slice eaten!
# Now eaten 981 slices!
# 0
# Another slice eaten!
# Now eaten 982 slices!
# 0
# Another slice eaten!
# Now eaten 983 slices!
# 0
# Another slice eaten!
# Now eaten 984 slices!
# 0
# Another slice eaten!
# Now eaten 985 slices!
# 0
# Another slice eaten!
# Now eaten 986 slices!
# 0
# Another slice eaten!
# Now eaten 987 slices!
# 0
# Another slice eaten!
# Now eaten 988 slices!
# 0
# Another slice eaten!
# Now eaten 989 slices!
# 0
# Another slice eaten!
# Now eaten 990 slices!
# 0
# Another slice eaten!
# Now eaten 991 slices!
# 0
# Another slice eaten!
# Now eaten 992 slices!
# 0
# Another slice eaten!
# Now eaten 993 slices!
# 0
# Another slice eaten!
# Now eaten 994 slices!
# 0
# Another slice eaten!
# Now eaten 995 slices!
# 0
# Another slice eaten!
# Now eaten 996 slices!
# 0
# Another slice eaten!
# Now eaten 997 slices!
# 0
# Another slice eaten!
# Now eaten 998 slices!
# 0
# Another slice eaten!
# Now eaten 999 slices!
# 0
# Another slice eaten!
# Now eaten 1000 slices!
# 0
# Another slice eaten!
# Now eaten 1001 slices!
# 0
# Another slice eaten!
# Now eaten 1002 slices!
# 0
# Another slice eaten!
# Now eaten 1003 slices!
# 0
# Another slice eaten!
# Now eaten 1004 slices!
# 0
# Another slice eaten!
# Now eaten 1005 slices!
# 0
# Another slice eaten!
# Now eaten 1006 slices!
# 0
# Another slice eaten!
# Now eaten 1007 slices!
# 0
# Another slice eaten!
# Now eaten 1008 slices!
# 0
# Another slice eaten!
# Now eaten 1009 slices!
# 0
# Another slice eaten!
# Now eaten 1010 slices!
# 0
# Another slice eaten!
# Now eaten 1011 slices!
# 0
# Another slice eaten!
# Now eaten 1012 slices!
# 0
# Another slice eaten!
# Now eaten 1013 slices!
# 0
# Another slice eaten!
# Now eaten 1014 slices!
# 0
# Another slice eaten!
# Now eaten 1015 slices!
# 0
# Another slice eaten!
# Now eaten 1016 slices!
# 0
# Another slice eaten!
# Now eaten 1017 slices!
# 0
# Another slice eaten!
# Now eaten 1018 slices!
# 0
# Another slice eaten!
# Now eaten 1019 slices!
# 0
# Another slice eaten!
# Now eaten 1020 slices!
# 0
# Another slice eaten!
# Now eaten 1021 slices!
# 0
# Another slice eaten!
# Now eaten 1022 slices!
# 0
# Another slice eaten!
# Now eaten 1023 slices!
# 0
# Another slice eaten!
# Now eaten 1024 slices!
# 0
# Another slice eaten!
# Now eaten 1025 slices!
# 0
# Another slice eaten!
# Now eaten 1026 slices!
# 0
# Another slice eaten!
# Now eaten 1027 slices!
# 0
# Another slice eaten!
# Now eaten 1028 slices!
# 0
# Another slice eaten!
# Now eaten 1029 slices!
# 0
# Another slice eaten!
# Now eaten 1030 slices!
# 0
# Another slice eaten!
# Now eaten 1031 slices!
# 0
# Another slice eaten!
# Now eaten 1032 slices!
# 0
# Another slice eaten!
# Now eaten 1033 slices!
# 0
# Another slice eaten!
# Now eaten 1034 slices!
# 0
# Another slice eaten!
# Now eaten 1035 slices!
# 0
# Another slice eaten!
# Now eaten 1036 slices!
# 0
# Another slice eaten!
# Now eaten 1037 slices!
# 0
# Another slice eaten!
# Now eaten 1038 slices!
# 0
# Another slice eaten!
# Now eaten 1039 slices!
# 0
# Another slice eaten!
# Now eaten 1040 slices!
# 0
# Another slice eaten!
# Now eaten 1041 slices!
# 0
# Another slice eaten!
# Now eaten 1042 slices!
# 0
# Another slice eaten!
# Now eaten 1043 slices!
# 0
# Another slice eaten!
# Now eaten 1044 slices!
# 0
# Another slice eaten!
# Now eaten 1045 slices!
# 0
# Another slice eaten!
# Now eaten 1046 slices!
# 0
# Another slice eaten!
# Now eaten 1047 slices!
# 0
# Another slice eaten!
# Now eaten 1048 slices!
# 0
# Another slice eaten!
# Now eaten 1049 slices!
# 0
# Another slice eaten!
# Now eaten 1050 slices!
# 0
# Another slice eaten!
# Now eaten 1051 slices!
# 0
# Another slice eaten!
# Now eaten 1052 slices!
# 0
# Another slice eaten!
# Now eaten 1053 slices!
# 0
# Another slice eaten!
# Now eaten 1054 slices!
# 0
# Another slice eaten!
# Now eaten 1055 slices!
# 0
# Another slice eaten!
# Now eaten 1056 slices!
# 0
# Another slice eaten!
# Now eaten 1057 slices!
# 0
# Another slice eaten!
# Now eaten 1058 slices!
# 0
# Another slice eaten!
# Now eaten 1059 slices!
# 0
# Another slice eaten!
# Now eaten 1060 slices!
# 0
# Another slice eaten!
# Now eaten 1061 slices!
# 0
# Another slice eaten!
# Now eaten 1062 slices!
# 0
# Another slice eaten!
# Now eaten 1063 slices!
# 0
# Another slice eaten!
# Now eaten 1064 slices!
# 0
# Another slice eaten!
# Now eaten 1065 slices!
# 0
# Another slice eaten!
# Now eaten 1066 slices!
# 0
# Another slice eaten!
# Now eaten 1067 slices!
# 0
# Another slice eaten!
# ...
# Now eaten 6037 slices!
# 0
# Another slice eaten!
# Now eaten 6038 slices!
# 0
# Another slice eaten!
# Now eaten 6039 slices!
# 0
# Another slice eaten!
# Now eaten 6040 slices!
# 0
# Another slice eaten!
# Now eaten 6041 slices!
# 0
# Another slice eaten!
# Now eaten 6042 slices!
# 0
# Another slice eaten!
# Now eaten 6043 slices!
# 0
# Another slice eaten!
# Now eaten 6044 slices!
# 0
# Another slice eaten!
# Now eaten 6045 slices!
# 0
# Another slice eaten!
# Now eaten 6046 slices!
# 0
# Another slice eaten!
# Now eaten 6047 slices!
# 0
# Another slice eaten!
# Now eaten 6048 slices!
# 0
# Another slice eaten!
# Now eaten 6049 slices!
# 0
# Another slice eaten!
# Now eaten 6050 slices!
# 0
# Another slice eaten!
# Now eaten 6051 slices!
# 0
# Another slice eaten!
# Now eaten 6052 slices!
# 0
# Another slice eaten!
# Now eaten 6053 slices!
# 0
# Another slice eaten!
# Now eaten 6054 slices!
# 0
# Another slice eaten!
# Now eaten 6055 slices!
# 0
# Another slice eaten!
# Now eaten 6056 slices!
# 0
# Another slice eaten!
# Now eaten 6057 slices!
# 0
# Another slice eaten!
# Now eaten 6058 slices!
# 0
# Another slice eaten!
# Now eaten 6059 slices!
# 0
# Another slice eaten!
# Now eaten 6060 slices!
# 0
# Another slice eaten!
# Now eaten 6061 slices!
# 0
# Another slice eaten!
# Now eaten 6062 slices!
# 0
# Another slice eaten!
# Now eaten 6063 slices!
# 0
# Another slice eaten!
# Now eaten 6064 slices!
# 0
# Another slice eaten!
# Now eaten 6065 slices!
# 0
# Another slice eaten!
# Now eaten 6066 slices!
# 0
# Another slice eaten!
# Now eaten 6067 slices!
# 0
# Another slice eaten!
# Now eaten 6068 slices!
# 0
# Another slice eaten!
# Now eaten 6069 slices!
# 0
# Another slice eaten!
# Now eaten 6070 slices!
# 0
# Another slice eaten!
# Now eaten 6071 slices!
# 0
# Another slice eaten!
# Now eaten 6072 slices!
# 0
# Another slice eaten!
# Now eaten 6073 slices!
# 0
# Another slice eaten!
# Now eaten 6074 slices!
# 0
# Another slice eaten!
# Now eaten 6075 slices!
# 0
# Another slice eaten!
# Now eaten 6076 slices!
# 0
# Another slice eaten!
# Now eaten 6077 slices!
# 0
# Another slice eaten!
# Now eaten 6078 slices!
# 0
# Another slice eaten!
# Now eaten 6079 slices!
# 0
# Another slice eaten!
# Now eaten 6080 slices!
# 0
# Another slice eaten!
# Now eaten 6081 slices!
# 0
# Another slice eaten!
# Now eaten 6082 slices!
# 0
# Another slice eaten!
# Now eaten 6083 slices!
# 0
# Another slice eaten!
# Now eaten 6084 slices!
# 0
# Another slice eaten!
# Now eaten 6085 slices!
# 0
# Another slice eaten!
# Now eaten 6086 slices!
# 0
# Another slice eaten!
# Now eaten 6087 slices!
# 0
# Another slice eaten!
# Now eaten 6088 slices!
# 0
# Another slice eaten!
# Now eaten 6089 slices!
# 0
# Another slice eaten!
# Now eaten 6090 slices!
# 0
# Another slice eaten!
# Now eaten 6091 slices!
# 0
# Another slice eaten!
# Now eaten 6092 slices!
# 0
# Another slice eaten!
# Now eaten 6093 slices!
# 0
# Another slice eaten!
# Now eaten 6094 slices!
# 0
# Another slice eaten!
# Now eaten 6095 slices!
# 0
# Another slice eaten!
# Now eaten 6096 slices!
# 0
# Another slice eaten!
# Now eaten 6097 slices!
# 0
# Another slice eaten!
# Now eaten 6098 slices!
# 0
# Another slice eaten!
# Now eaten 6099 slices!
# 0
# Another slice eaten!
# Now eaten 6100 slices!
# 0
# Another slice eaten!
# Now eaten 6101 slices!
# 0
# Another slice eaten!
# Now eaten 6102 slices!
# 0
# Another slice eaten!
# Now eaten 6103 slices!
# 0
# Another slice eaten!
# Now eaten 6104 slices!
# 0
# Another slice eaten!
# Now eaten 6105 slices!
# 0
# Another slice eaten!
# Now eaten 6106 slices!
# 0
# Another slice eaten!
# Now eaten 6107 slices!
# 0
# Another slice eaten!
# Now eaten 6108 slices!
# 0
# Another slice eaten!
# Now eaten 6109 slices!
# 0
# Another slice eaten!
# Now eaten 6110 slices!
# 0
# Another slice eaten!
# Now eaten 6111 slices!
# 0
# Another slice eaten!
# Now eaten 6112 slices!
# 0
# Another slice eaten!
# Now eaten 6113 slices!
# 0
# Another slice eaten!
# Now eaten 6114 slices!
# 0
# Another slice eaten!
# Now eaten 6115 slices!
# 0
# Another slice eaten!
# Now eaten 6116 slices!
# 0
# Another slice eaten!
# Now eaten 6117 slices!
# 0
# Another slice eaten!
# Now eaten 6118 slices!
# 0
# Another slice eaten!
# Now eaten 6119 slices!
# 0
# Another slice eaten!
# Now eaten 6120 slices!
# 0
# Another slice eaten!
# Now eaten 6121 slices!
# 0
# Another slice eaten!
# Now eaten 6122 slices!
# 0
# Another slice eaten!
# Now eaten 6123 slices!
# 0
# Another slice eaten!
# Now eaten 6124 slices!
# 0
# Another slice eaten!
# Now eaten 6125 slices!
# 0
# Another slice eaten!
# Now eaten 6126 slices!
# 0
# Another slice eaten!
# Now eaten 6127 slices!
# 0
# Another slice eaten!
# Now eaten 6128 slices!
# 0
# Another slice eaten!
# Now eaten 6129 slices!
# 0
# Another slice eaten!
# Now eaten 6130 slices!
# 0
# Another slice eaten!
# Now eaten 6131 slices!
# 0
# Another slice eaten!
# Now eaten 6132 slices!
# 0
# Another slice eaten!
# Now eaten 6133 slices!
# 0
# Another slice eaten!
# Now eaten 6134 slices!
# 0
# Another slice eaten!
# Now eaten 6135 slices!
# 0
# Another slice eaten!
# Now eaten 6136 slices!
# 0
# Another slice eaten!
# Now eaten 6137 slices!
# 0
# Another slice eaten!
# Now eaten 6138 slices!
# 0
# Another slice eaten!
# Now eaten 6139 slices!
# 0
# Another slice eaten!
# Now eaten 6140 slices!
# 0
# Another slice eaten!
# Now eaten 6141 slices!
# 0
# Another slice eaten!
# Now eaten 6142 slices!
# 0
# Another slice eaten!
# Now eaten 6143 slices!
# 0
# Another slice eaten!
# Now eaten 6144 slices!
# 0
# Another slice eaten!
# Now eaten 6145 slices!
# 0
# Another slice eaten!
# Now eaten 6146 slices!
# 0
# Another slice eaten!
# Now eaten 6147 slices!
# 0
# Another slice eaten!
# Now eaten 6148 slices!
# 0
# Another slice eaten!
# Now eaten 6149 slices!
# 0
# Another slice eaten!
# Now eaten 6150 slices!
# 0
# Another slice eaten!
# Now eaten 6151 slices!
# 0
# Another slice eaten!
# Now eaten 6152 slices!
# 0
# Another slice eaten!
# Now eaten 6153 slices!
# 0
# Another slice eaten!
# Now eaten 6154 slices!
# 0
# Another slice eaten!
# Now eaten 6155 slices!
# 0
# Another slice eaten!
# Now eaten 6156 slices!
# 0
# Another slice eaten!
# Now eaten 6157 slices!
# 0
# Another slice eaten!
# Now eaten 6158 slices!
# 0
# Another slice eaten!
# Now eaten 6159 slices!
# 0
# Another slice eaten!
# Now eaten 6160 slices!
# 0
# Another slice eaten!
# Now eaten 6161 slices!
# 0
# Another slice eaten!
# Now eaten 6162 slices!
# 0
# Another slice eaten!
# Now eaten 6163 slices!
# 0
# Another slice eaten!
# Now eaten 6164 slices!
# 0
# Another slice eaten!
# Now eaten 6165 slices!
# 0
# Another slice eaten!
# Now eaten 6166 slices!
# 0
# Another slice eaten!
# Now eaten 6167 slices!
# 0
# Another slice eaten!
# Now eaten 6168 slices!
# 0
# Another slice eaten!
# Now eaten 6169 slices!
# 0
# Another slice eaten!
# Now eaten 6170 slices!
# 0
# Another slice eaten!
# Now eaten 6171 slices!
# 0
# Another slice eaten!
# Now eaten 6172 slices!
# 0
# Another slice eaten!
# Now eaten 6173 slices!
# 0
# Another slice eaten!
# Now eaten 6174 slices!
# 0
# Another slice eaten!
# Now eaten 6175 slices!
# 0
# Another slice eaten!
# Now eaten 6176 slices!
# 0
# Another slice eaten!
# Now eaten 6177 slices!
# 0
# Another slice eaten!
# Now eaten 6178 slices!
# 0
# Another slice eaten!
# Now eaten 6179 slices!
# 0
# Another slice eaten!
# Now eaten 6180 slices!
# 0
# Another slice eaten!
# Now eaten 6181 slices!
# 0
# Another slice eaten!
# Now eaten 6182 slices!
# 0
# Another slice eaten!
# Now eaten 6183 slices!
# 0
# Another slice eaten!
# Now eaten 6184 slices!
# 0
# Another slice eaten!
# Now eaten 6185 slices!
# 0
# Another slice eaten!
# Now eaten 6186 slices!
# 0
# Another slice eaten!
# Now eaten 6187 slices!
# 0
# Another slice eaten!
# Now eaten 6188 slices!
# 0
# Another slice eaten!
# Now eaten 6189 slices!
# 0
# Another slice eaten!
# Now eaten 6190 slices!
# 0
# Another slice eaten!
# Now eaten 6191 slices!
# 0
# Another slice eaten!
# Now eaten 6192 slices!
# 0
# Another slice eaten!
# Now eaten 6193 slices!
# 0
# Another slice eaten!
# Now eaten 6194 slices!
# 0
# Another slice eaten!
# Now eaten 6195 slices!
# 0
# Another slice eaten!
# Now eaten 6196 slices!
# 0
# Another slice eaten!
# Now eaten 6197 slices!
# 0
# Another slice eaten!
# Now eaten 6198 slices!
# 0
# Another slice eaten!
# Now eaten 6199 slices!
# 0
# Another slice eaten!
# Now eaten 6200 slices!
# 0
# Another slice eaten!
# Now eaten 6201 slices!
# 0
# Another slice eaten!
# Now eaten 6202 slices!
# 0
# Another slice eaten!
# Now eaten 6203 slices!
# 0
# Another slice eaten!
# Now eaten 6204 slices!
# 0
# Another slice eaten!
# Now eaten 6205 slices!
# 0
# Another slice eaten!
# Now eaten 6206 slices!
# 0
# Another slice eaten!
# Now eaten 6207 slices!
# 0
# Another slice eaten!
# Now eaten 6208 slices!
# 0
# Another slice eaten!
# Now eaten 6209 slices!
# 0
# Another slice eaten!
# Now eaten 6210 slices!
# 0
# Another slice eaten!
# Now eaten 6211 slices!
# 0
# Another slice eaten!
# Now eaten 6212 slices!
# 0
# Another slice eaten!
# Now eaten 6213 slices!
# 0
# Another slice eaten!
# Now eaten 6214 slices!
# 0
# Another slice eaten!
# Now eaten 6215 slices!
# 0
# Another slice eaten!
# Now eaten 6216 slices!
# 0
# Another slice eaten!
# Now eaten 6217 slices!
# 0
# Another slice eaten!
# Now eaten 6218 slices!
# 0
# Another slice eaten!
# Now eaten 6219 slices!
# 0
# Another slice eaten!
# Now eaten 6220 slices!
# 0
# Another slice eaten!
# Now eaten 6221 slices!
# 0
# Another slice eaten!
# Now eaten 6222 slices!
# 0
# Another slice eaten!
# Now eaten 6223 slices!
# 0
# Another slice eaten!
# Now eaten 6224 slices!
# 0
# Another slice eaten!
# Now eaten 6225 slices!
# 0
# Another slice eaten!
# Now eaten 6226 slices!
# 0
# Another slice eaten!
# Now eaten 6227 slices!
# 0
# Another slice eaten!
# Now eaten 6228 slices!
# 0
# Another slice eaten!
# Now eaten 6229 slices!
# 0
# Another slice eaten!
# Now eaten 6230 slices!
# 0
# Another slice eaten!
# Now eaten 6231 slices!
# 0
# Another slice eaten!
# Now eaten 6232 slices!
# 0
# Another slice eaten!
# Now eaten 6233 slices!
# 0
# Another slice eaten!
# Now eaten 6234 slices!
# 0
# Another slice eaten!
# Now eaten 6235 slices!
# 0
# Another slice eaten!
# Now eaten 6236 slices!
# 0
# Another slice eaten!
# Now eaten 6237 slices!
# 0
# Another slice eaten!
# Now eaten 6238 slices!
# 0
# Another slice eaten!
# Now eaten 6239 slices!
# 0
# Another slice eaten!
# Now eaten 6240 slices!
# 0
# Another slice eaten!
# Now eaten 6241 slices!
# 0
# Another slice eaten!
# Now eaten 6242 slices!
# 0
# Another slice eaten!
# Now eaten 6243 slices!
# 0
# Another slice eaten!
# Now eaten 6244 slices!
# 0
# Another slice eaten!
# Now eaten 6245 slices!
# 0
# Another slice eaten!
# Now eaten 6246 slices!
# 0
# Another slice eaten!
# Now eaten 6247 slices!
# 0
# Another slice eaten!
# Now eaten 6248 slices!
# 0
# Another slice eaten!
# Now eaten 6249 slices!
# 0
# Another slice eaten!
# Now eaten 6250 slices!
# 0
# Another slice eaten!
# Now eaten 6251 slices!
# 0
# Another slice eaten!
# Now eaten 6252 slices!
# 0
# Another slice eaten!
# Now eaten 6253 slices!
# 0
# Another slice eaten!
# Now eaten 6254 slices!
# 0
# Another slice eaten!
# Now eaten 6255 slices!
# 0
# Another slice eaten!
# Now eaten 6256 slices!
# 0
# Another slice eaten!
# Now eaten 6257 slices!
# 0
# Another slice eaten!
# Now eaten 6258 slices!
# 0
# Another slice eaten!
# Now eaten 6259 slices!
# 0
# Another slice eaten!
# Now eaten 6260 slices!
# 0
# Another slice eaten!
# Now eaten 6261 slices!
# 0
# Another slice eaten!
# Now eaten 6262 slices!
# 0
# Another slice eaten!
# Now eaten 6263 slices!
# 0
# Another slice eaten!
# Now eaten 6264 slices!
# 0
# Another slice eaten!
# Now eaten 6265 slices!
# 0
# Another slice eaten!
# Now eaten 6266 slices!
# 0
# Another slice eaten!
# Now eaten 6267 slices!
# 0
# Another slice eaten!
# Now eaten 6268 slices!
# 0
# Another slice eaten!
# Now eaten 6269 slices!
# 0
# Another slice eaten!
# Now eaten 6270 slices!
# 0
# Another slice eaten!
# Now eaten 6271 slices!
# 0
# Another slice eaten!
# Now eaten 6272 slices!
# 0
# Another slice eaten!
# Now eaten 6273 slices!
# 0
# Another slice eaten!
# Now eaten 6274 slices!
# 0
# Another slice eaten!
# Now eaten 6275 slices!
# 0
# Another slice eaten!
# Now eaten 6276 slices!
# 0
# Another slice eaten!
# Now eaten 6277 slices!
# 0
# Another slice eaten!
# Now eaten 6278 slices!
# 0
# Another slice eaten!
# Now eaten 6279 slices!
# 0
# Another slice eaten!
# Now eaten 6280 slices!
# 0
# Another slice eaten!
# Now eaten 6281 slices!
# 0
# Another slice eaten!
# Now eaten 6282 slices!
# 0
# Another slice eaten!
# Now eaten 6283 slices!
# 0
# Another slice eaten!
# Now eaten 6284 slices!
# 0
# Another slice eaten!
# Now eaten 6285 slices!
# 0
# Another slice eaten!
# Now eaten 6286 slices!
# 0
# Another slice eaten!
# Now eaten 6287 slices!
# 0
# Another slice eaten!
# Now eaten 6288 slices!
# 0
# Another slice eaten!
# Now eaten 6289 slices!
# 0
# Another slice eaten!
# Now eaten 6290 slices!
# 0
# Another slice eaten!
# Now eaten 6291 slices!
# 0
# Another slice eaten!
# Now eaten 6292 slices!
# 0
# Another slice eaten!
# Now eaten 6293 slices!
# 0
# Another slice eaten!
# Now eaten 6294 slices!
# 0
# Another slice eaten!
# Now eaten 6295 slices!
# 0
# Another slice eaten!
# Now eaten 6296 slices!
# 0
# Another slice eaten!
# Now eaten 6297 slices!
# 0
# Another slice eaten!
# Now eaten 6298 slices!
# 0
# Another slice eaten!
# Now eaten 6299 slices!
# 0
# Another slice eaten!
# Now eaten 6300 slices!
# 0
# Another slice eaten!
# Now eaten 6301 slices!
# 0
# Another slice eaten!
# Now eaten 6302 slices!
# 0
# Another slice eaten!
# Now eaten 6303 slices!
# 0
# Another slice eaten!
# Now eaten 6304 slices!
# 0
# Another slice eaten!
# Now eaten 6305 slices!
# 0
# Another slice eaten!
# Now eaten 6306 slices!
# 0
# Another slice eaten!
# Now eaten 6307 slices!
# 0
# Another slice eaten!
# Now eaten 6308 slices!
# 0
# Another slice eaten!
# Now eaten 6309 slices!
# 0
# Another slice eaten!
# Now eaten 6310 slices!
# 0
# Another slice eaten!
# Now eaten 6311 slices!
# 0
# Another slice eaten!
# Now eaten 6312 slices!
# 0
# Another slice eaten!
# Now eaten 6313 slices!
# 0
# Another slice eaten!
# Now eaten 6314 slices!
# 0
# Another slice eaten!
# Now eaten 6315 slices!
# 0
# Another slice eaten!
# Now eaten 6316 slices!
# 0
# Another slice eaten!
# Now eaten 6317 slices!
# 0
# Another slice eaten!
# Now eaten 6318 slices!
# 0
# Another slice eaten!
# Now eaten 6319 slices!
# 0
# Another slice eaten!
# Now eaten 6320 slices!
# 0
# Another slice eaten!
# Now eaten 6321 slices!
# 0
# Another slice eaten!
# Now eaten 6322 slices!
# 0
# Another slice eaten!
# Now eaten 6323 slices!
# 0
# Another slice eaten!
# Now eaten 6324 slices!
# 0
# Another slice eaten!
# Now eaten 6325 slices!
# 0
# Another slice eaten!
# Now eaten 6326 slices!
# 0
# Another slice eaten!
# Now eaten 6327 slices!
# 0
# Another slice eaten!
# Now eaten 6328 slices!
# 0
# Another slice eaten!
# Now eaten 6329 slices!
# 0
# Another slice eaten!
# Now eaten 6330 slices!
# 0
# Another slice eaten!
# Now eaten 6331 slices!
# 0
# Another slice eaten!
# Now eaten 6332 slices!
# 0
# Another slice eaten!
# Now eaten 6333 slices!
# 0
# Another slice eaten!
# Now eaten 6334 slices!
# 0
# Another slice eaten!
# Now eaten 6335 slices!
# 0
# Another slice eaten!
# Now eaten 6336 slices!
# 0
# Another slice eaten!
# Now eaten 6337 slices!
# 0
# Another slice eaten!
# Now eaten 6338 slices!
# 0
# Another slice eaten!
# Now eaten 6339 slices!
# 0
# Another slice eaten!
# Now eaten 6340 slices!
# 0
# Another slice eaten!
# Now eaten 6341 slices!
# 0
# Another slice eaten!
# Now eaten 6342 slices!
# 0
# Another slice eaten!
# Now eaten 6343 slices!
# 0
# Another slice eaten!
# Now eaten 6344 slices!
# 0
# Another slice eaten!
# Now eaten 6345 slices!
# 0
# Another slice eaten!
# Now eaten 6346 slices!
# 0
# Another slice eaten!
# Now eaten 6347 slices!
# 0
# Another slice eaten!
# Now eaten 6348 slices!
# 0
# Another slice eaten!
# Now eaten 6349 slices!
# 0
# Another slice eaten!
# Now eaten 6350 slices!
# 0
# Another slice eaten!
# Now eaten 6351 slices!
# 0
# Another slice eaten!
# Now eaten 6352 slices!
# 0
# Another slice eaten!
# Now eaten 6353 slices!
# 0
# Another slice eaten!
# Now eaten 6354 slices!
# 0
# Another slice eaten!
# Now eaten 6355 slices!
# 0
# Another slice eaten!
# Now eaten 6356 slices!
# 0
# Another slice eaten!
# Now eaten 6357 slices!
# 0
# Another slice eaten!
# Now eaten 6358 slices!
# 0
# Another slice eaten!
# Now eaten 6359 slices!
# 0
# Another slice eaten!
# Now eaten 6360 slices!
# 0
# Another slice eaten!
# Now eaten 6361 slices!
# 0
# Another slice eaten!
# Now eaten 6362 slices!
# 0
# Another slice eaten!
# Now eaten 6363 slices!
# 0
# Another slice eaten!
# Now eaten 6364 slices!
# 0
# Another slice eaten!
# Now eaten 6365 slices!
# 0
# Another slice eaten!
# Now eaten 6366 slices!
# 0
# Another slice eaten!
# Now eaten 6367 slices!
# 0
# Another slice eaten!
# Now eaten 6368 slices!
# 0
# Another slice eaten!
# Now eaten 6369 slices!
# 0
# Another slice eaten!
# Now eaten 6370 slices!
# 0
# Another slice eaten!
# Now eaten 6371 slices!
# 0
# Another slice eaten!
# Now eaten 6372 slices!
# 0
# Another slice eaten!
# Now eaten 6373 slices!
# 0
# Another slice eaten!
# Now eaten 6374 slices!
# 0
# Another slice eaten!
# Now eaten 6375 slices!
# 0
# Another slice eaten!
# Now eaten 6376 slices!
# 0
# Another slice eaten!
# Now eaten 6377 slices!
# 0
# Another slice eaten!
# Now eaten 6378 slices!
# 0
# Another slice eaten!
# Now eaten 6379 slices!
# 0
# Another slice eaten!
# Now eaten 6380 slices!
# 0
# Another slice eaten!
# Now eaten 6381 slices!
# 0
# Another slice eaten!
# Now eaten 6382 slices!
# 0
# Another slice eaten!
# Now eaten 6383 slices!
# 0
# Another slice eaten!
# Now eaten 6384 slices!
# 0

# %%
time_for_breakfast = 1468 # in seconds
number_of_cooked_pancakes = 0
# use a while loop to make yourself 5 pancakes for breakfast
# each pancake takes 27 seconds to cook on each side
# it takes an average of 5 seconds to flip a pancake, add or remove a pancake from the pan.
# you must decrease the time_for_breakfast each time you 
# add a pancake to the skillet (frying pan) or flip a pancake (i.e. 2 times per pancake)
# there is only room for one pancake at a time

# %% [markdown]
# ## For Loops

# %% [markdown]
# > **Hint:** You may find the [remove method](https://www.programiz.com/python-programming/methods/list/remove) to be useful for the next problem

# %%
line_of_hungry_patrons = list(range(0,30))
fed_patrons = []
# use a while loop to feed the hungry patrons who have an even number
# add the patrons with an even number to the fed_patrons list
# then remove the even numbered patrons from the line_of_hungry_patrons
# each list should contain 15 elements

# %% [markdown]
# ### `break` And `continue` Statements

# %% [markdown]
# We have a list of person objects with all kinds of attributes. We'll use loops to find a person that meets a certain requirement that we are looking for or create new lists with a certain subset of elements. Write for loops with conditional statements in conjunction with `break` and `continue` to get the desired output.

# %%
people = [
    {'name': "Daniel", 'age': 29, 'job': "Engineer", 'pet': "Cat", 'pet_name': "Gato"}, 
    {'name': "Katie", 'age': 30, 'job': "Teacher", 'pet': "Dog", 'pet_name': "Frank"},
    {'name': "Owen", 'age': 26, 'job': "Sales person", 'pet': "Cat", 'pet_name': "Cosmo"},
    {'name': "Josh", 'age': 22, 'job': "Student", 'pet': "Cat", 'pet_name': "Chat"},
    {'name': "Estelle", 'age': 35, 'job': "French Diplomat", 'pet': "Dog", 'pet_name': "Gabby"},
    {'name': "Gustav", 'age': 24, 'job': "Brewer", 'pet': "Dog", 'pet_name': "Helen"}
]

# %%
# use the for loop below to find the *first* person in the list of people that has a dog as their pet
# the iteration count shouldn't exceed 2 iterations
first_dog_person = None
iteration_count = 0
for person in people:
    iteration_count += 1
    pass

# %%
# use a for loop to create a list of the cat owners who are under the age of 28
cat_owners = None
# for loop goes here

# %%
# use a for loop to find the first person who is above 29 years old in our list of people
# remember to use a break and or continue statement
thirty_something_yr_old = None
# for loop goes here

# %%
# use a for loop to create a list of person names and another list of pet names for all dog owners
dog_owner_names = None
dog_names = None
# for loop goes here

# %%
# use a for loop to create a list of odd numbers from the list of numbers from 0 to 100
# each time there is an odd number, add 10 to it and append it to the list_of_odd_numbers_plus_ten
# stop adding numbers to the list when there are 35 numbers
# use break and continue statements in your code
list_of_numbers = list(range(0,100))
list_of_odd_numbers_plus_ten = []
for number in list_of_numbers:
    pass

# %% [markdown]
# ## Summary

# %% [markdown]
# In this lab, we practiced using while loops, which continue executing their block of code until the given condition is no longer truthy. This is useful for instances where we do not have a collection or do not need a collection to solve our problem, especially when we would only like to stop the process according to a certain condition. We then practiced using control flow statements, `break` and `continue`, to selectively operate on elements, append them to new lists, or assign them to new variables.
